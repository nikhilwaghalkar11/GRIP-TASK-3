# %% [markdown]
# # <span style="color: green;">GRIP- THE SPARKS FOUNDATION </span>
# ## Data Science & Business Analytics Internship
# ## Exploratory Data Analysis - Retail
# # NAME :- Nikhil Waghalkar

# %% [markdown]
# ### -------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ##  Tasks :-
# * Perform ‘Exploratory Data Analysis’ on dataset ‘SampleSuperstore’
#
# * As a business manager, try to find out the weak areas where you can work to make more profit.
#
# * What all business problems you can derive by exploring the data?
#
# * I used Python to perform EDA on this dataset.
#
# Dataset: https://bit.ly/3i4rbWl

# %% [markdown]
# ##### 1. Import the required libraires

# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ##### 2. Importing Data

# %%
df = pd.read_csv("SampleSuperstore.csv")
print("Data imported...👍")
# Out:
# Data imported...👍

# %% [markdown]
# ##### 3.Knowing data

# %%
df.head() # seeing the head of data
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
print(f"shape of the data is {df.shape}")
# Out:
# shape of the data is (9994, 13)

# %% [markdown]
# ##### 4. EDA

# %%
print("Basic info about data...")
df.info()
# Out:
# Basic info about data...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
print("Basic descriptive stats for numerical columns...")
df.describe().T
# Out:
# Basic descriptive stats for numerical columns...
#               count          mean           std       min          25%  \
# Postal Code  9994.0  55190.379428  32063.693350  1040.000  23223.00000
# Sales        9994.0    229.858001    623.245101     0.444     17.28000
# Quantity     9994.0      3.789574      2.225110     1.000      2.00000
# Discount     9994.0      0.156203      0.206452     0.000      0.00000
# Profit       9994.0     28.656896    234.260108 -6599.978      1.72875
#
#                     50%        75%        max
# Postal Code  56430.5000  90008.000  99301.000
# Sales           54.4900    209.940  22638.480
# Quantity         3.0000      5.000     14.000
# Discount         0.2000      0.200      0.800
# Profit           8.6665     29.364   8399.976

# %%
print("counting classes in each categorical columns...")
for i in df.select_dtypes("O"):
    print("->",i,len(df[i].unique()))
# Out:
# counting classes in each categorical columns...
# -> Ship Mode 4
# -> Segment 3
# -> Country 1
# -> City 531
# -> State 49
# -> Region 4
# -> Category 3
# -> Sub-Category 17

# %% [markdown]
# ##### 4.1 checking for nulls

# %%
df.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %% [markdown]
# ##### 4.3 Data Visualizations

# %%
sns.pairplot(df) # pairplot to check relation in numerical columns

# %%
print("heat map to check correlation in numerical columns...")
fig,axes = plt.subplots(1,1,figsize=(12,7))
sns.heatmap(df.corr(),annot=True)
plt.show()
# Out:
# heat map to check correlation in numerical columns...

# %% [markdown]
# ##### Sales and profit is highly correlated amoung all which quit obvious

# %% [markdown]
# ##### 4.4 Univariate analysis

# %%
plt.figure(figsize=(15,6))
plt.subplot(1,2,1)
sns.distplot(df["Profit"])
plt.subplot(1,2,2)
sns.distplot(df["Sales"])
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.histplot(df["Discount"],bins=5)
plt.show()

# %% [markdown]
# ##### 4.5 Multivariate analysis

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x="Sales",y="Profit",hue="Segment",data=df,size="Discount")
plt.title("sales vs profit ")
plt.show()

# %%
sns.barplot(x="Region",y="Profit",data=df,estimator=np.sum)
plt.title("profit by Region")
plt.show()

# %%
plt.figure(figsize=(15,6))
df.groupby(by=["Category","Sub-Category"])["Profit"].mean().plot(kind="bar")
plt.ylabel("profit")
plt.title("profit by categories and sub-categories")
plt.show()

# %%
plt.figure(figsize=(15,6))
df.groupby(by=["Category","Sub-Category"])["Sales"].mean().plot(kind="bar")
plt.ylabel("profit")
plt.title("profit by categories and sub-categories")
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.heatmap(pd.crosstab(df["Region"],df["Quantity"]))
# Out:
# <AxesSubplot:xlabel='Quantity', ylabel='Region'>

# %% [markdown]
# # Results of EDA
#
# * #### The features Profit and Sales are highly related.
# * #### West and East region have more profit .
# * #### The maximum quantity of product in demand was in range 2-4 in all regions.
# * #### category technology has highest contribution in profit.
# * #### The Office supplies provides low Sales.
